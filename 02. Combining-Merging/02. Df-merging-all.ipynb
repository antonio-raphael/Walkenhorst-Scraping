# %%
# Load necessary packages
import pandas as pd
import os
import fuzzywuzzy
from fuzzywuzzy import fuzz, process # run 'pip install python-Levenshtein' in the terminal before importing this
import rapidfuzz
from rapidfuzz import process, fuzz
# Out:
# /Users/Louise/anaconda3/envs/Webscraping_environment/lib/python3.10/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
os.getcwd()
# Out:
# '/Users/Louise/Desktop/Master/M1/S2/Data_viz/Project/code'

# %%
# Import datasets
df_catalogue = pd.read_csv("../data/intermediate/Scraped_Catalogue.csv")
df_w_cat = pd.read_csv("../data/intermediate/Full-Products-Data/Products_Categories.csv")
#df_w_without = pd.read_csv("../data/intermediate/Full-Products-Data/Products_Only.csv")

df_walmart = df_w_cat.copy()

# %%
df_catalogue.head()
# Out:
#    Unnamed: 0  X    Category                                         item  \
# 0           1  1  ASIAN FOOD   A Taste of Thai Green Curry Paste 1.75 oz.
# 1           2  2  ASIAN FOOD      A Taste of Thai Pad Thai Sauce 3.25 oz.
# 2           3  3  ASIAN FOOD  A Taste of Thai Panang Curry Paste 1.75 oz.
# 3           4  4  ASIAN FOOD     A Taste of Thai Peanut Sauce Mix 3.5 oz.
# 4           5  5  ASIAN FOOD     A Taste of Thai Red Curry Paste 1.75 oz.
#
#   item_number  kosher  price     weight category_clean
# 0   22668-399   False  $2.45  1.75  oz.     ASIAN FOOD
# 1   22668-408   False  $2.95  3.25  oz.     ASIAN FOOD
# 2   22668-409   False  $2.45  1.75  oz.     ASIAN FOOD
# 3   22668-414   False  $2.95   3.5  oz.     ASIAN FOOD
# 4    3111-998   False  $2.45  1.75  oz.     ASIAN FOOD

# %%
df_walmart.head()
# Out:
#                     source_file  \
# 0       walmart_asian_food.json
# 1    walmart_bottled-water.json
# 2            walmart_bread.json
# 3            walmart_bread.json
# 4  walmart_candy_sugarfree.json
#
#                                                 name unit_price unit_type  \
# 0  Freshness Guaranteed Hot and Ready-to-Eat Chic...        NaN       NaN
# 1            TAL Stainless Steel Ranger Water Bottle        NaN       NaN
# 2      Freshness Guaranteed French Bakery Bread Loaf        NaN       NaN
# 3   Freshness Guaranteed Sourdough Bakery Bread Loaf        NaN       NaN
# 4  RUSSELL STOVER Sugar Free Caramel Chocolate Ca...        NaN       NaN
#
#    clean_unit_price
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
# Create names datasets
walmart_names = df_walmart['name']
catalogue_names = df_catalogue['item']

# Remove all special characters and numbers from the names to keep only letters in lowercase, in the walmart dataset
import re
def clean_name(name):
    # Remove special characters and numbers using regex
    cleaned_name = re.sub(r'[^A-Za-z\s]', '', name)
    # Convert to lowercase
    cleaned_name = cleaned_name.lower()
    return cleaned_name

df_walmart['name'] = df_walmart['name'].apply(clean_name)

# Keep only unique names in the walmart dataset
df_walmart = df_walmart.drop_duplicates(subset=['name'])

# %%
# Remove all "number + oz" patterns from the names, and the special characters, to keep only letters in lowercase, in the catalogue dataset
def clean_catalogue_name(name):
    # Remove "number + oz" patterns using regex
    cleaned_name = re.sub(r'\b\d+\s*oz\b', '', name, flags=re.IGNORECASE)
    # Remove special characters and numbers using regex
    cleaned_name = re.sub(r'[^A-Za-z\s]', '', cleaned_name)
    # Convert to lowercase
    cleaned_name = cleaned_name.lower()
    return cleaned_name

df_catalogue['item'] = df_catalogue['item'].apply(clean_catalogue_name)

# Keep only relevant columns in the catalogue dataset
df_catalogue = df_catalogue[['item','kosher','price', 'weight', 'category_clean']]

# %%
df_walmart.head()
# Out:
#                     source_file  \
# 0       walmart_asian_food.json
# 1    walmart_bottled-water.json
# 2            walmart_bread.json
# 3            walmart_bread.json
# 4  walmart_candy_sugarfree.json
#
#                                                 name unit_price unit_type  \
# 0  freshness guaranteed hot and readytoeat chicke...        NaN       NaN
# 1            tal stainless steel ranger water bottle        NaN       NaN
# 2      freshness guaranteed french bakery bread loaf        NaN       NaN
# 3   freshness guaranteed sourdough bakery bread loaf        NaN       NaN
# 4  russell stover sugar free caramel chocolate ca...        NaN       NaN
#
#    clean_unit_price
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df_catalogue.head()
# Out:
#                                   item  kosher  price     weight  \
# 0   a taste of thai green curry paste    False  $2.45  1.75  oz.
# 1      a taste of thai pad thai sauce    False  $2.95  3.25  oz.
# 2  a taste of thai panang curry paste    False  $2.45  1.75  oz.
# 3    a taste of thai peanut sauce mix    False  $2.95   3.5  oz.
# 4     a taste of thai red curry paste    False  $2.45  1.75  oz.
#
#   category_clean
# 0     ASIAN FOOD
# 1     ASIAN FOOD
# 2     ASIAN FOOD
# 3     ASIAN FOOD
# 4     ASIAN FOOD

# %%
# Function to get the best matches between two datasets
def get_matches(small_df_names, large_df_names):
    results = {}
    
    # Convert large_df_names to string to avoid issues with NoneType
    large_df_names = [str(n) for n in large_df_names if n is not None]
    
    for name in small_df_names:
        if pd.isna(name) or name == "": continue
        
        match = process.extractOne(
            str(name), 
            large_df_names, 
            scorer=fuzz.token_sort_ratio
        )
        
        if match:
            results[name] = {'walmart_match': match[0], 'score': match[1]}
            
    return results

# Execute the matching function with Walkenhorst as reference
matches_dict = get_matches(df_catalogue['item'].unique(), df_walmart['name'].unique())

# Transform the matches dictionary into a DataFrame
df_matches = pd.DataFrame.from_dict(matches_dict, orient='index').reset_index()
df_matches.columns = ['item', 'walmart_match', 'match_score']

# %%
# Transform the matches dictionary into a DataFrame
df_matches = pd.DataFrame.from_dict(matches_dict, orient='index').reset_index()
df_matches.columns = ['item', 'walmart_match', 'match_score']
df_matches = df_matches.sort_values(by = 'match_score', ascending = False)

# Keep only matches with a score of 60 or higher
df_matches = df_matches[df_matches['match_score'] >= 65]
df_matches
# Out:
#                                             item  \
# 3424            smartfood popcorn white cheddar
# 713               justins almond butter classic
# 659                  best foods real mayonnaise
# 3426            smartfood white cheddar popcorn
# 699                          heinz sweet relish
# ...                                          ...
# 1734   tasty bite indian vegetable tikka masala
# 751   melindas creamy style habanero wing sauce
# 2800                        marinela choco roles
# 3074  snack factory pretzel crisps buffalo wing
# 922         fudge covered nutter butter cookies
#
#                                       walmart_match  match_score
# 3424                smartfood popcorn white cheddar        100.0
# 713                   justins classic almond butter        100.0
# 659                      best foods real mayonnaise        100.0
# 3426                smartfood popcorn white cheddar        100.0
# 699                              heinz sweet relish        100.0
# ...                                             ...          ...
# 1734       tasty bite organic chickpea tikka masala         65.0
# 751         buffalo wild wings mango habanero sauce         65.0
# 2800                           martins hoagie rolls         65.0
# 3074        franks redhot kosher buffalo wing sauce         65.0
# 922   oreo fudge covered chocolate sandwich cookies         65.0
#
# [1562 rows x 3 columns]

# %%
# Merge with the catalogue dataset
df_merged = pd.merge(df_catalogue, df_matches, on='item', how='right')
len(df_merged)
# Out:
# 1610

# %%
# Merge with the walmart dataset
df_walmart = df_walmart.drop_duplicates(subset=['name'])
df_final = pd.merge(df_merged, df_walmart, left_on='walmart_match', right_on='name', how='left')

# %%
# Rename and keep only relevant columns in the final dataframe
df_final = df_final.rename(columns={'item': 'Walkenhorst_product', 'price': 'Walkenhorst_price', 'weight': 'Walkenhorst_weight', 'category_clean': 'Walkenhorst_Category', 'source_file': 'Walmart_category', 'name' : 'Walmart_product', 'unit_price': 'Walmart_unit_price', 'unit_type' : 'Walmart_unit_type', 'clean_unit_price' : 'Walmart_clean_unit_price' })
df_final.drop(columns=['walmart_match'], inplace=True)
df_final
# Out:
#                              Walkenhorst_product  kosher Walkenhorst_price  \
# 0               smartfood popcorn white cheddar    False             $6.95
# 1                 justins almond butter classic     True             $1.95
# 2                    best foods real mayonnaise    False             $7.95
# 3               smartfood white cheddar popcorn    False             $3.75
# 4                            heinz sweet relish     True             $3.75
# ...                                          ...     ...               ...
# 1605   tasty bite indian vegetable tikka masala     True             $4.45
# 1606  melindas creamy style habanero wing sauce    False             $5.45
# 1607                        marinela choco roles   False             $2.95
# 1608  snack factory pretzel crisps buffalo wing    False             $2.45
# 1609        fudge covered nutter butter cookies     True             $7.45
#
#      Walkenhorst_weight          Walkenhorst_Category  match_score  \
# 0             6.75  oz.                        SNACKS        100.0
# 1             1.15  oz.  CONDIMENTS, SAUCES & SPREADS        100.0
# 2             11.5  oz.  CONDIMENTS, SAUCES & SPREADS        100.0
# 3                2  oz.                        SNACKS        100.0
# 4             12.7  oz.  CONDIMENTS, SAUCES & SPREADS        100.0
# ...                 ...                           ...          ...
# 1605            10  oz.                 MEALS & SIDES         65.0
# 1606            12  oz.  CONDIMENTS, SAUCES & SPREADS         65.0
# 1607            NA  oz.                      PASTRIES         65.0
# 1608             3  oz.                        SNACKS         65.0
# 1609           7.9  oz.                       COOKIES         65.0
#
#              Walmart_category                                Walmart_product  \
# 0        walmart_popcorn.json                smartfood popcorn white cheddar
# 1        walmart_spreads.json                  justins classic almond butter
# 2     walmart_condiments.json                     best foods real mayonnaise
# 3        walmart_popcorn.json                smartfood popcorn white cheddar
# 4     walmart_condiments.json                             heinz sweet relish
# ...                       ...                                            ...
# 1605  walmart_asian_food.json       tasty bite organic chickpea tikka masala
# 1606   walmart-hot-sauce.json        buffalo wild wings mango habanero sauce
# 1607       walmart_bread.json                           martins hoagie rolls
# 1608      walmart_sauces.json        franks redhot kosher buffalo wing sauce
# 1609     walmart_cookies.json  oreo fudge covered chocolate sandwich cookies
#
#      Walmart_unit_price Walmart_unit_type  Walmart_clean_unit_price
# 0                   NaN   price per ounce                  0.631667
# 1                   NaN   price per ounce                  0.695000
# 2                   NaN   price per ounce                  0.271000
# 3                   NaN   price per ounce                  0.631667
# 4                   NaN   price per ounce                  0.206000
# ...                 ...               ...                       ...
# 1605                NaN   price per ounce                  0.384000
# 1606                NaN   price per ounce                  0.287000
# 1607                NaN   price per ounce                  0.213000
# 1608                NaN   price per ounce                  0.229000
# 1609                NaN   price per ounce                  0.528000
#
# [1610 rows x 11 columns]

# %%
# Export the final dataframe to a CSV file
df_final.to_csv("../data/processed/Merged_Walkenhorst_Walmart.csv")
